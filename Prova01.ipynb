# %%
class No:
    def __init__(self, valor):
        self.valor = valor
        self.proximo = None

class ListaEncadeada:
    def __init__(self):
        self.inicio = None
    def inserir(self, valor):
        novo_no = No(valor)
        if self.inicio is None:
            self.inicio = novo_no
        else:
            atual = self.inicio
            while atual.proximo:
                atual = atual.proximo
            atual.proximo = novo_no
            
    def contar(self):
        contador = 0
        atual = self.inicio

        while atual:        
            contador += 1
            atual = atual.proximo

        return contador

# %%
lista = ListaEncadeada()

print("Inserindo números na lista encadeada:")
lista.inserir(5)
lista.inserir(15)
lista.inserir(25)

print(lista.contar())
# Out:
# Inserindo números na lista encadeada:
# 3
